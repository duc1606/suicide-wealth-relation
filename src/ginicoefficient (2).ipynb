# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("csv_files/Gini_Coefficient.csv")

# %%
df.head()
# Out:
#                  country  giniWB  yearWB  giniCIA  yearCIA    pop2021
# 0           South Africa    63.0  2014.0     63.0   2014.0  60041.994
# 1                Namibia    59.1  2015.0     59.1   2015.0   2587.344
# 2               Suriname    57.9  1999.0      NaN      NaN    591.800
# 3                 Zambia    57.1  2015.0     57.1   2015.0  18920.651
# 4  Sao Tome and Principe    56.3  2017.0     56.3   2017.0    223.368

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  176 non-null    object
#  1   giniWB   163 non-null    float64
#  2   yearWB   163 non-null    float64
#  3   giniCIA  165 non-null    float64
#  4   yearCIA  165 non-null    float64
#  5   pop2021  176 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 8.4+ KB

# %%
# Assuming df is your DataFrame and it has been defined earlier

# List of selected countries in the specified order
selected_countries_ordered = [
    "Slovenia", "Bulgaria", "Austria", "Lithuania", "Switzerland", "Hungary",
    "France", "Estonia", "Latvia", "Croatia", "Finland", "Russia",
    "Sri Lanka", "Nicaragua", "Canada", "Italy", "Turkmenistan", "Denmark",
    "Luxembourg", "United Kingdom", "Czechia", "Germany", "Oman", "Cuba",
    "Belgium", "Ukraine", "Serbia", "Barbados", "Norway", "Puerto Rico",
    "Sweden", "Israel", "Belarus", "Singapore", "El Salvador", "Kyrgyzstan"
]

# Filter the DataFrame for the selected countries
filtered_df = df[df['country'].isin(selected_countries_ordered)]

# Ensure the countries are ordered as per the given list
filtered_df['country'] = pd.Categorical(filtered_df['country'], categories=selected_countries_ordered, ordered=True)
filtered_df = filtered_df.sort_values('country')

# Calculate the average Gini coefficient of the selected countries
average_gini = filtered_df['giniWB'].mean()

# Create the bar plot
plt.figure(figsize=(12, 8))
plt.bar(filtered_df['country'], filtered_df['giniWB'], color='skyblue')
plt.axhline(average_gini, color='red', linestyle='--', label=f'Average Gini Coefficient: {average_gini:.2f}')
plt.xlabel('Country')
plt.ylabel('Gini Coefficient')
plt.title('Gini Coefficients of Selected Countries')
plt.xticks(rotation=90)
plt.legend()
plt.tight_layout()
plt.show()

# Print the average Gini coefficient
print(f"The average Gini Coefficient of the selected countries is: {average_gini:.2f}")
# Out:
# /tmp/ipykernel_33/3476190500.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['country'] = pd.Categorical(filtered_df['country'], categories=selected_countries_ordered, ordered=True)
# The average Gini Coefficient of the selected countries is: 33.13

# %%
# List of selected countries in the specified order
selected_countries_ordered_new = [
    "South Africa", "Malta", "Guyana", "Guatemala", "Cyprus", "Turkey",
    "Chile", "Paraguay", "Montenegro", "Philippines", "Suriname", "Brazil",
    "Korea, Republic of", "Mexico", "Bosnia and Herzegovina"
]

# Filter the DataFrame for the selected countries
filtered_df = df[df['country'].isin(selected_countries_ordered_new)]

# Ensure the countries are ordered as per the given list
filtered_df['country'] = pd.Categorical(filtered_df['country'], categories=selected_countries_ordered_new, ordered=True)
filtered_df = filtered_df.sort_values('country')

# Calculate the average Gini coefficient of the selected countries
average_gini = filtered_df['giniWB'].mean()

# Create the bar plot
plt.figure(figsize=(12, 8))
plt.bar(filtered_df['country'], filtered_df['giniWB'], color='skyblue')
plt.axhline(average_gini, color='red', linestyle='--', label=f'Average Gini Coefficient: {average_gini:.2f}')
plt.xlabel('Country')
plt.ylabel('Gini Coefficient')
plt.title('Gini Coefficients of Selected Countries')
plt.xticks(rotation=90)
plt.legend()
plt.tight_layout()
plt.show()

# Print the average Gini coefficient
print(f"The average Gini Coefficient of the selected countries is: {average_gini:.2f}")
# Out:
# /tmp/ipykernel_33/232982160.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['country'] = pd.Categorical(filtered_df['country'], categories=selected_countries_ordered_new, ordered=True)
# The average Gini Coefficient of the selected countries is: 44.31

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is your DataFrame and it has been defined earlier

# Combined list of selected countries in the specified order, with specified countries removed
combined_countries_ordered = [
    "Slovenia", "Bulgaria", "Austria", "Lithuania", "Switzerland", "Hungary",
    "France", "Estonia", "Latvia", "Croatia", "Finland", "Russia",
    "Sri Lanka", "Nicaragua", "Canada", "Italy", "Turkmenistan", "Denmark",
    "Luxembourg", "United Kingdom", "Czech Republic", "Germany", "Belgium", "Ukraine",
    "Serbia", "Norway", "Sweden", "Israel", "Belarus", "Singapore", "El Salvador",
    "Kyrgyzstan", "Kazakhstan", "Kiribati", "Australia", "Mauritius", "Slovakia",
    "New Zealand", "Panama", "Netherlands", "Argentina", "Saint Lucia", "Thailand",
    "Maldives", "Fiji", "Romania", "Uzbekistan", "Trinidad and Tobago", "Iceland",
    "Azerbaijan", "Greece", "Spain", "Albania", "Armenia", "Seychelles", "Mongolia",
    "United States", "Qatar", "United Arab Emirates", "Georgia",
    "Japan", "Colombia", "Portugal", "Jamaica", "Costa Rica", "Ireland", "Ecuador",
    "Poland", "Belize", "Uruguay", "South Africa", "Malta", "Guyana", "Guatemala",
    "Cyprus", "Turkey", "Chile", "Paraguay", "Montenegro", "Philippines", "Suriname",
    "Brazil","South Korea", "Mexico", "Bosnia and Herzegovina"
]

# Filter the DataFrame for the combined list of countries
filtered_df = df[df['country'].isin(combined_countries_ordered)]

# Add specified Gini coefficient values
additional_gini_values = {
    "Singapore": 45.9,
    "Slovakia": 24.1,
    "New Zealand": 33.9,
    "Qatar": 41.1
}

for country, gini_value in additional_gini_values.items():
    filtered_df.loc[filtered_df['country'] == country, 'giniWB'] = gini_value

# Ensure the countries are ordered as per the combined list
filtered_df['country'] = pd.Categorical(filtered_df['country'], categories=combined_countries_ordered, ordered=True)
filtered_df = filtered_df.sort_values('country')

# Create a numerical index for the countries
filtered_df['index'] = range(len(filtered_df))

# Create the bar plot
plt.figure(figsize=(18, 12))
sns.barplot(x='country', y='giniWB', data=filtered_df, palette='YlOrRd')
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Gini Coefficient')
plt.title('Gini Coefficients of Selected Countries')

# Add a trend line using the numerical index
sns.regplot(x='index', y='giniWB', data=filtered_df, scatter=False, color='blue')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_33/3422406749.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['country'] = pd.Categorical(filtered_df['country'], categories=combined_countries_ordered, ordered=True)
# /opt/conda/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
